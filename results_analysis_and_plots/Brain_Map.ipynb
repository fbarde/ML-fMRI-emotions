# %% [markdown]
# ## General aim of this notebook
# This notebook aims at creating a brain map to visualize the feature importance

# %%
from nilearn import plotting

# Visualizing t-map image on EPI template with manual
# positioning of coordinates using cut_coords given as a list

stat_img = 'HO_Weighted_all.nii.gz'
fig=plotting.plot_stat_map(stat_img,vmax = 5 ,threshold = 2,cut_coords=[-47, -32, 5], draw_cross = False,black_bg = False )

fig.savefig('C:/Users/manon/Desktop/Projet_2 _ML/figures/Brain_Map.jpg')
